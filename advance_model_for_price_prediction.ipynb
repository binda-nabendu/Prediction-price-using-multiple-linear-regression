# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data-set\\CarPrice_Assignment.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.drop(['car_ID', 'symboling', 'CarName', 'fueltype','aspiration', 'doornumber', 'carbody','drivewheel','enginelocation','cylindernumber','fuelsystem'], axis=1, inplace= True)

# %%
df
# Out:
#      wheelbase  carlength  carwidth  carheight  curbweight enginetype  \
# 0         88.6      168.8      64.1       48.8        2548       dohc
# 1         88.6      168.8      64.1       48.8        2548       dohc
# 2         94.5      171.2      65.5       52.4        2823       ohcv
# 3         99.8      176.6      66.2       54.3        2337        ohc
# 4         99.4      176.6      66.4       54.3        2824        ohc
# ..         ...        ...       ...        ...         ...        ...
# 200      109.1      188.8      68.9       55.5        2952        ohc
# 201      109.1      188.8      68.8       55.5        3049        ohc
# 202      109.1      188.8      68.9       55.5        3012       ohcv
# 203      109.1      188.8      68.9       55.5        3217        ohc
# 204      109.1      188.8      68.9       55.5        3062        ohc
#
#      enginesize  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# ...

# %%
import hashlib


def string_to_hash(value):
    hash_object = hashlib.sha256(value.encode())
    return int(hash_object.hexdigest(), 16) % 100

# %%
# for i in df:
#     if df.enginetype == 'dohc':
#         df.enginetype = int(1)
#     elif df.enginetype == 'ohc':
#         df.enginetype = int(2)
#     elif df.enginetype == 'ahcv':
#         df.enginetype = int(3)
df['enginetype'] = df['enginetype'].apply(string_to_hash)

# %%
df
# Out:
#      wheelbase  carlength  carwidth  carheight  curbweight  enginetype  \
# 0         88.6      168.8      64.1       48.8        2548          14
# 1         88.6      168.8      64.1       48.8        2548          14
# 2         94.5      171.2      65.5       52.4        2823          78
# 3         99.8      176.6      66.2       54.3        2337          15
# 4         99.4      176.6      66.4       54.3        2824          15
# ..         ...        ...       ...        ...         ...         ...
# 200      109.1      188.8      68.9       55.5        2952          15
# 201      109.1      188.8      68.8       55.5        3049          15
# 202      109.1      188.8      68.9       55.5        3012          78
# 203      109.1      188.8      68.9       55.5        3217          15
# 204      109.1      188.8      68.9       55.5        3062          15
#
#      enginesize  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# ...

# %%
df.describe()
# Out:
#         wheelbase   carlength    carwidth   carheight   curbweight  \
# count  205.000000  205.000000  205.000000  205.000000   205.000000
# mean    98.756585  174.049268   65.907805   53.724878  2555.565854
# std      6.021776   12.337289    2.145204    2.443522   520.680204
# min     86.600000  141.100000   60.300000   47.800000  1488.000000
# 25%     94.500000  166.300000   64.100000   52.000000  2145.000000
# 50%     97.000000  173.200000   65.500000   54.100000  2414.000000
# 75%    102.400000  183.100000   66.900000   55.500000  2935.000000
# max    120.900000  208.100000   72.300000   59.800000  4066.000000
#
#        enginetype  enginesize   boreratio      stroke  compressionratio  \
# count  205.000000  205.000000  205.000000  205.000000        205.000000
# mean    24.014634  126.907317    3.329756    3.255415         10.142537
# std     19.886314   41.642693    0.270844    0.313597          3.972040
# min     14.000000   61.000000    2.540000    2.070000          7.000000
# ...

# %%
df.columns
# Out:
# Index(['wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight',
#        'enginetype', 'enginesize', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
sns.pairplot(df)
# Out:
# C:\Users\Nabendu\anaconda3\envs\Prediction-price-using-multiple-linear-regression\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.distplot(df['price'])
# Out:
# C:\Users\Nabendu\AppData\Local\Temp\ipykernel_8860\4207564571.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight',
#        'enginetype', 'enginesize', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
x = df[['wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight',
       'enginetype', 'enginesize', 'boreratio', 'stroke', 'compressionratio',
       'horsepower', 'peakrpm', 'citympg', 'highwaympg']]

# %%
y = df['price']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= .25, random_state=33)

# %%
from  sklearn.linear_model import LinearRegression

# %%
liner_regression_model = LinearRegression()

# %%
liner_regression_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
liner_regression_model.predict(x_test)
# Out:
# array([11203.88147579, 32324.69796767, 11012.34215308, 10986.65666843,
#        20609.5391076 , 18771.14144144, 29894.40690362, 27106.28581684,
#         6523.93475927, 19719.39004031, 17231.04822549, 16147.90309689,
#         6024.23000229, 12111.40724468,  7031.60981287, 18512.75465211,
#        13856.28370665,  8954.81703065,  7680.22197568, 12678.86249341,
#        23503.59907995, 10656.58867139, 14285.54502007, 15620.21877863,
#        27069.57078481, 21834.14646776, 15645.16006471,  5714.20732504,
#        10969.72702437, 16804.99272447,  7489.4293807 , 26174.73712222,
#        17335.51981568, 17747.36446879, 13846.41563048,  9330.25482644,
#         5178.52621761,  6020.35168427, 10809.06991844,  5657.26636071,
#        35997.39524707,  6430.58684639,  7198.78559699, 22400.2003001 ,
#        20993.57551003,  4829.08602863,  9478.58449282,  6453.95673651,
#        10898.41044616, 10299.50278841, 10002.91028964, 10379.60037086])

# %%
y_test
# Out:
# 87      9279.0
# 47     32250.0
# 188     9995.0
# 145    11259.0
# 181    15750.0
# 200    16845.0
# 17     36880.0
# 15     30760.0
# 76      5389.0
# 204    22625.0
# 111    15580.0
# 137    18620.0
# 118     5572.0
# 166     9538.0
# 156     6938.0
# 8      23875.0
# 167     8449.0
# 34      7129.0
# 155     8778.0
# 174    10698.0
# 202    21485.0
# 38      9095.0
# 171    11549.0
# 29     12964.0
# 128    37028.0
# 104    17199.0
# 191    13295.0
# 93      7349.0
# 193    12290.0
# 197    16515.0
# 120     6229.0
# 68     28248.0
# 14     24565.0
# 110    13860.0
# 168     9639.0
# 144     9233.0
# 54      7395.0
# 91      6649.0
# 159     7788.0
# 154     7898.0
# 129    31400.5
# 152     6488.0
# 162     9258.0
# 179    15998.0
# 103    13499.0
# 50      5195.0
# 27      8558.0
# 44      8916.5
# 42     10345.0
# 182     7775.0
# 62     10245.0
# 100     9549.0
# Name: price, dtype: float64

# %%
liner_regression_model.coef_
# Out:
# array([ 2.13369830e+02, -1.22062984e+02,  4.54359595e+02, -3.04602439e+01,
#         2.46701904e+00, -2.03521625e+01,  1.13544500e+02, -6.98590369e+02,
#        -3.11446996e+03,  3.44397724e+02,  3.22293723e+01,  2.40914929e+00,
#        -3.30673446e+02,  2.15272427e+02])

# %%
pd.DataFrame(liner_regression_model.coef_, x.columns, columns = ['Coefficient'])
# Out:
#                   Coefficient
# wheelbase          213.369830
# carlength         -122.062984
# carwidth           454.359595
# carheight          -30.460244
# curbweight           2.467019
# enginetype         -20.352162
# enginesize         113.544500
# boreratio         -698.590369
# stroke           -3114.469965
# compressionratio   344.397724
# horsepower          32.229372
# peakrpm              2.409149
# citympg           -330.673446
# highwaympg         215.272427
